# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1188DQBNnxXgxxZoldO8cXiQFYaO9PoOh?usp=sharing)
#
# 2. [Практический ноутбук 1](https://colab.research.google.com/drive/1EcHhwOCIhvm4mpxEbDGRawIJ4BpbAyqO?usp=sharing)
#
# 3. [Практический ноутбук 2](https://colab.research.google.com/drive/1pHONL5J4AVraE-SYJnpes7KdicPsD9qt?usp=sharing)
#
# 3. Практический ноутбук 3

# %% [markdown]
# В финальном ноутбуке занятия мы создадим сегментриующую модель на базе изображений самолетов. Эта задача значительно проще предыдущей, поскольку на оригинальном изображении будет всего два класса объектов:
# - самолет
# - фон

# %% [markdown]
# ## Подключение бибилиотек

# %%
# Основа для модели нейронной сети
from tensorflow.keras.models import Model

# Стандартные слои keras
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization

# Оптимизатор Adam
from tensorflow.keras.optimizers import Adam

# Дополнительные утилиты keras
from tensorflow.keras import utils

# Инструменты для построения графиков
import matplotlib.pyplot as plt

# Инструменты для работы с изображениями
from tensorflow.keras.preprocessing import image

# Инструменты для работы с массивами
import numpy as np

# Системные инструменты
import time, random, gdown, os

# Дополнительные инструменты для работы с изображениями
from PIL import Image

# Дополнительные инструменты визуализации
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# ## Загрузка датасета

# %% [markdown]
# По аналогии с базой "Стройка" подготовим необходимые данные для обучения сети для базы "Самолеты"

# %%
# Загрузка датасета из облака

gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/airplane_456x256.zip', None, quiet=True)
#gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/airplane_912x512.zip', None, quiet=True)
#gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l14/airplane_1920x1080.zip', None, quiet=True)
# Out:
# 'airplane_456x256.zip'

# %%
# Распаковка архива

# !unzip -qo airplane_456x256.zip

# %% [markdown]
# Для данного занятия возьмем уменьшенный размер изображений (**456x256** пикселей). При наличии достаточных вычислительных мощностей вы можете воспользоваться базой с бОльшим разрешением.

# %%
# Глобальные параметры

IMG_WIDTH = 256               # Ширина картинки
IMG_HEIGHT = 456              # Высота картинки
CLASS_COUNT = 2               # Количество классов на изображении
TRAIN_DIRECTORY = 'train'     # Название папки с файлами обучающей выборки
VAL_DIRECTORY = 'val'         # Название папки с файлами проверочной выборки

# %%
# Служебная функция загрузки выборки изображений из файлов в папке

def load_imageset(folder,   # имя папки
                  subset,   # подмножество изображений - оригинальные или сегментированные
                  title     # имя выборки
                  ):

    # Cписок для хранения изображений выборки
    image_list = []

    # Отметка текущего времени
    cur_time = time.time()

    # Для всех файлов в каталоге по указанному пути:
    for filename in sorted(os.listdir(f'{folder}/{subset}')):

        # Чтение очередной картинки и добавление ее в список изображений требуемого размера
        image_list.append(image.load_img(os.path.join(f'{folder}/{subset}', filename),
                                         target_size=(IMG_WIDTH, IMG_HEIGHT)))

    # Вывод времени загрузки картинок выборки
    print('{} выборка загружена. Время загрузки: {:.2f} с'.format(title,
                                                                  time.time() - cur_time))

    # Вывод количества элементов в выборке
    print('Количество изображений:', len(image_list))

    return image_list

# %%
# Функция для просмотра изображений из набора

def show_imageset(image_list,  # выборка изображений
                  n            # количество картинок для просмотра
                  ):

    fig, axs = plt.subplots(1, n, figsize=(25, 10))       # Создание полотна из n графиков

    # Вывод в цикле n случайных изображений
    for i in range(n):
        img = random.choice(image_list)                   # Выборка случайного фото для отображения
        axs[i].axis('off')
        axs[i].imshow(img)                                # Отображение картинки

    plt.show()                                            # Отрисовка изображений

# %%
# Загрузка входных изображений

train_images = load_imageset(TRAIN_DIRECTORY, 'original', 'Обучающая')
val_images = load_imageset(VAL_DIRECTORY, 'original', 'Проверочная')
# Out:
# Обучающая выборка загружена. Время загрузки: 0.26 с
# Количество изображений: 931
# Проверочная выборка загружена. Время загрузки: 0.01 с
# Количество изображений: 50

# %%
# Просмотр входных изображений из обучающего набора

show_imageset(train_images, 5)

# %%
# Загрузка выходных (сегментированных) изображений

train_segments = load_imageset(TRAIN_DIRECTORY, 'segment', 'Обучающая')
val_segments = load_imageset(VAL_DIRECTORY, 'segment', 'Проверочная')
# Out:
# Обучающая выборка загружена. Время загрузки: 0.25 с
# Количество изображений: 931
# Проверочная выборка загружена. Время загрузки: 0.01 с
# Количество изображений: 50

# %%
# Просмотр сегментированных изображений из обучающего набора

show_imageset(train_segments, 5)

# %%
# Цвета пикселов сегментированных изображений

AIRPLANE = (255, 255, 255)      # Самолет (белый)
BACKGROUND = (0, 0, 0)          # Фон (черный)

# %%
CLASS_LABELS = (AIRPLANE, BACKGROUND)

# %% [markdown]
# ## Создание выборки

# %% [markdown]
# Переведем сегментированные изображения в одноканальные сегментированные с номером класса в каждом пикселе (функции из практики №1):

# %%
# Функция преобразования цветного сегментированного изображения в метки классов

def rgb_to_labels(image_list  # список цветных изображений
                 ):

    result = []

    # Для всех картинок в списке:
    for d in image_list:
        sample = np.array(d)
        # Создание пустой 1-канальной картики
        y = np.zeros((IMG_WIDTH, IMG_HEIGHT, 1), dtype='uint8')

        # По всем классам:
        for i, cl in enumerate(CLASS_LABELS):
            # Нахождение 3-х канальных пикселей классов и занесение метки класса
            y[np.where(np.all(sample == CLASS_LABELS[i], axis=-1))] = i

        result.append(y)

    return np.array(result)

# %% [markdown]
# Обратная функция, перевод одноканальных сегментированных изображений с номером класса в каждом пикселе в 3х канальное RGB сегментированное изображение:

# %%
# Функция преобразования тензора меток класса в цветное сегметрированное изображение

def labels_to_rgb(image_list  # список одноканальных изображений
                 ):

    result = []

    # Для всех картинок в списке:
    for y in image_list:
        # Создание пустой цветной картики
        temp = np.zeros((IMG_WIDTH, IMG_HEIGHT, 3), dtype='uint8')

        # По всем классам:
        for i, cl in enumerate(CLASS_LABELS):
            # Нахождение пикселов класса и заполнение цветом из CLASS_LABELS[i]
            temp[np.where(np.all(y==i, axis=-1))] = CLASS_LABELS[i]

        result.append(temp)

    return np.array(result)

# %% [markdown]
# Сформируем выборки:

# %%
# Формирование обучающей выборки

x_train = []                          # Cписок под обучающую выборку

for img in train_images:              # Для всех изображений выборки:
    x = image.img_to_array(img)       # Перевод изображения в numpy-массив формы: высота x ширина x количество каналов
    x_train.append(x)                 # Добавление элемента в x_train

x_train = np.array(x_train)           # Перевод всей выборки в numpy
print(x_train.shape)                  # Форма x_train
# Out:
# (931, 256, 456, 3)

# %%
# Формирование проверочной выборки

x_val = []                            # Cписок под проверочную выборку

for img in val_images:                # Для всех изображений выборки:
    x = image.img_to_array(img)       # Перевод изображения в numpy-массив формы: высота x ширина x количество каналов
    x_val.append(x)                   # Добавление элемента в x_train

x_val = np.array(x_val)               # Перевод всей выборки в numpy
print(x_val.shape)                    # Форма x_train
# Out:
# (50, 256, 456, 3)

# %%
# Преобразование сегментов в метки классов

y_train = rgb_to_labels(train_segments)
y_val = rgb_to_labels(val_segments)

print(y_train.shape)
print(y_val.shape)
# Out:
# (931, 256, 456, 1)
# (50, 256, 456, 1)

# %% [markdown]
# Для начала попробуем простую линейную модель:

# %%
def sequential_segmentation_net(class_count,  # количество классов
                                input_shape   # форма входного изображения
                                ):

    img_input = Input(input_shape)                                              # Создаем входной слой формой input_shape
    x = Conv2D(128, (3, 3), padding='same', name='block1_conv1')(img_input)     # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv3')(x)              # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                                   # Добавляем слой Activation

    x = Conv2D(32, (3, 3), padding='same', name='block1_conv4')(x)              # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)

    x = Conv2D(16, (3, 3), padding='same', name='block1_conv5')(x)              # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                                 # Добавляем слой BatchNormalization
    x = Activation('relu')(x)

    x = Conv2D(class_count, (3, 3), activation='softmax', padding='same')(x)    # Добавляем Conv2D-Слой с softmax-активацией на class_count-нейронов

    model = Model(img_input, x)                                                 # Создаем модель с входом 'img_input' и выходом 'x'

    # Компилируем модель
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    # Возвращаем сформированную модель
    return model

# %%
# Создание модели и вывод сводки по архитектуре

model_seq = sequential_segmentation_net(CLASS_COUNT,
                                       (IMG_WIDTH, IMG_HEIGHT, 3))

model_seq.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 256, 456, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 256, 456, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 256, 456, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_23 (Activation)      │ (None, 256, 456, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv3 (Conv2D)           │ (None, 256, 456, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 256, 456, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_24 (Activation)      │ (None, 256, 456, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv4 (Conv2D)           │ (None, 256, 456, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 256, 456, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_25 (Activation)      │ (None, 256, 456, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv5 (Conv2D)           │ (None, 256, 456, 16)   │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 256, 456, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_26 (Activation)      │ (None, 256, 456, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 256, 456, 2)    │           290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,714 (397.32 KB)
#  Trainable params: 101,234 (395.45 KB)
#  Non-trainable params: 480 (1.88 KB)

# %%
# Обучение модели

history = model_seq.fit(x_train, y_train,
                        epochs=50, batch_size=16,
                        validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 70s 564ms/step - loss: 0.8216 - sparse_categorical_accuracy: 0.5333 - val_loss: 0.3783 - val_sparse_categorical_accuracy: 0.8857
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 32s 346ms/step - loss: 0.4318 - sparse_categorical_accuracy: 0.9148 - val_loss: 0.5288 - val_sparse_categorical_accuracy: 0.8412
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.3001 - sparse_categorical_accuracy: 0.9433 - val_loss: 0.4399 - val_sparse_categorical_accuracy: 0.8503
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 350ms/step - loss: 0.2453 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.3016 - val_sparse_categorical_accuracy: 0.9061
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 20s 346ms/step - loss: 0.2111 - sparse_categorical_accuracy: 0.9496 - val_loss: 0.2210 - val_sparse_categorical_accuracy: 0.9426
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 347ms/step - loss: 0.1875 - sparse_categorical_accuracy: 0.9478 - val_loss: 0.2012 - val_sparse_categorical_accuracy: 0.9390
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.2045 - val_sparse_categorical_accuracy: 0.9321
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 351ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.1769 - val_sparse_categorical_accuracy: 0.9503
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 350ms/step - loss: 0.1386 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1515 - val_sparse_categorical_accuracy: 0.9443
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 352ms/step - loss: 0.1195 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.1256 - val_sparse_categorical_accuracy: 0.9534
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 354ms/step - loss: 0.1253 - sparse_categorical_accuracy: 0.9572 - val_loss: 0.1233 - val_sparse_categorical_accuracy: 0.9544
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 353ms/step - loss: 0.1086 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.1155 - val_sparse_categorical_accuracy: 0.9569
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 349ms/step - loss: 0.1212 - sparse_categorical_accuracy: 0.9586 - val_loss: 0.1254 - val_sparse_categorical_accuracy: 0.9521
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 353ms/step - loss: 0.1072 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.1028 - val_sparse_categorical_accuracy: 0.9608
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 348ms/step - loss: 0.1042 - sparse_categorical_accuracy: 0.9634 - val_loss: 0.1085 - val_sparse_categorical_accuracy: 0.9559
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.1036 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.0984 - val_sparse_categorical_accuracy: 0.9624
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 20s 346ms/step - loss: 0.1041 - sparse_categorical_accuracy: 0.9626 - val_loss: 0.1137 - val_sparse_categorical_accuracy: 0.9585
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 20s 346ms/step - loss: 0.0975 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1036 - val_sparse_categorical_accuracy: 0.9623
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.0932 - val_sparse_categorical_accuracy: 0.9616
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 346ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.0958 - val_sparse_categorical_accuracy: 0.9617
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - loss: 0.1018 - sparse_categorical_accuracy: 0.9631 - val_loss: 0.0850 - val_sparse_categorical_accuracy: 0.9683
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 351ms/step - loss: 0.0916 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.1033 - val_sparse_categorical_accuracy: 0.9633
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - loss: 0.0909 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.1112 - val_sparse_categorical_accuracy: 0.9564
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 351ms/step - loss: 0.0840 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.0797 - val_sparse_categorical_accuracy: 0.9714
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 350ms/step - loss: 0.0848 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.0910 - val_sparse_categorical_accuracy: 0.9684
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 352ms/step - loss: 0.0807 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.0781 - val_sparse_categorical_accuracy: 0.9709
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - loss: 0.0830 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.1054 - val_sparse_categorical_accuracy: 0.9577
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.0831 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.1309 - val_sparse_categorical_accuracy: 0.9450
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 349ms/step - loss: 0.0767 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.0800 - val_sparse_categorical_accuracy: 0.9689
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - loss: 0.0730 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.2232 - val_sparse_categorical_accuracy: 0.9015
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 347ms/step - loss: 0.0823 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.0764 - val_sparse_categorical_accuracy: 0.9727
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 353ms/step - loss: 0.0748 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0731 - val_sparse_categorical_accuracy: 0.9721
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 350ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.2605 - val_sparse_categorical_accuracy: 0.8819
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.0717 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.0739 - val_sparse_categorical_accuracy: 0.9745
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 350ms/step - loss: 0.0746 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0713 - val_sparse_categorical_accuracy: 0.9748
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 345ms/step - loss: 0.0774 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.0778 - val_sparse_categorical_accuracy: 0.9703
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 350ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8534
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 351ms/step - loss: 0.0766 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.0814 - val_sparse_categorical_accuracy: 0.9728
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 350ms/step - loss: 0.0717 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.0744 - val_sparse_categorical_accuracy: 0.9741
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 349ms/step - loss: 0.0693 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0652 - val_sparse_categorical_accuracy: 0.9772
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 353ms/step - loss: 0.0710 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.0717 - val_sparse_categorical_accuracy: 0.9750
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 354ms/step - loss: 0.0669 - sparse_categorical_accuracy: 0.9751 - val_loss: 0.0815 - val_sparse_categorical_accuracy: 0.9726
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 350ms/step - loss: 0.0698 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0851 - val_sparse_categorical_accuracy: 0.9719
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 353ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.0670 - val_sparse_categorical_accuracy: 0.9771
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.0653 - sparse_categorical_accuracy: 0.9752 - val_loss: 0.0710 - val_sparse_categorical_accuracy: 0.9750
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 346ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9755 - val_loss: 0.1054 - val_sparse_categorical_accuracy: 0.9585
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 354ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.0892 - val_sparse_categorical_accuracy: 0.9689
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 41s 353ms/step - loss: 0.0710 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.0663 - val_sparse_categorical_accuracy: 0.9769
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 357ms/step - loss: 0.0700 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.0949 - val_sparse_categorical_accuracy: 0.9627
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 40s 346ms/step - loss: 0.0676 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0686 - val_sparse_categorical_accuracy: 0.9768

# %%
# Отображение графиков обучения модели

plt.figure(figsize=(14, 7))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.show()

# %% [markdown]
# Мы получили довольно неплохие результаты. **0.97** - очень хороший показатель для проверочной выборки.
#
# Теперь взглянем на результат работы нашей модели:

# %%
# Функция визуализации процесса сегментации изображений, модифицированная для вывода по списку индексов

def process_images(model,                       # обученная модель
                   count=1,                     # количество случайных картинок для сегментации
                   indexes=None,                # список индексов изображений в проверочной выборке
                   ):

    if indexes is None:
        # Генерация случайного списка индексов в количестве count между (0, len(x_val)
        indexes = np.random.randint(0, len(x_val), count)
    else:
        count = len(indexes)

    # Вычисление предсказания сети для картинок с отобранными индексами
    predict = np.argmax(model.predict(x_val[indexes]), axis=-1)

    # Подготовка цветов классов для отрисовки предсказания
    orig = labels_to_rgb(predict[..., None])
    fig, axs = plt.subplots(3, count, figsize=(25, 10))

    # Отрисовка результата работы модели
    for i in range(count):
        # Отображение на графике в первой линии предсказания модели
        axs[0, 0].set_title('Результат работы модели:')
        axs[0, i].imshow(orig[i])
        axs[0, i].axis('off')

        # Отображение на графике во второй линии сегментированного изображения из y_val
        axs[1, 0].set_title('Оригинальное сегментированное')
        axs[1, i].imshow(val_segments[indexes[i]])
        axs[1 ,i].axis('off')

        # Отображение на графике в третьей линии оригинального изображения
        axs[2, 0].set_title('Оригинальное изображение')
        axs[2, i].imshow(val_images[indexes[i]])
        axs[2 ,i].axis('off')

    plt.show()

# %% [markdown]
# **Распознавание**

# %%
# Отображение результатов работы модели

process_images(model_seq, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step

# %% [markdown]
# Очень даже неплохо! Теперь мы вправе расчитывать, что получим отличные результаты с более мощной архитектурой, например, **U-Net**.

# %% [markdown]
# ## Архитектура U-Net

# %%
def unet(class_count,   # количество классов
         input_shape    # форма входного изображения
         ):

    img_input = Input(input_shape)                                          # Создаем входной слой формой input_shape

    ''' Block 1 '''
    x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(img_input)  # Добавляем Conv2D-слой с 64-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)          # Добавляем Conv2D-слой с 64-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_1_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_1_out

    x = MaxPooling2D()(block_1_out)                                         # Добавляем слой MaxPooling2D

    ''' Block 2 '''
    x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)         # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)         # Добавляем Conv2D-слой с 128-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_2_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_2_out

    x = MaxPooling2D()(block_2_out)                                         # Добавляем слой MaxPooling2D

    ''' Block 3 '''
    x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)         # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)         # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv3')(x)         # Добавляем Conv2D-слой с 256-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_3_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_3_out

    x = MaxPooling2D()(block_3_out)                                         # Добавляем слой MaxPooling2D

    ''' Block 4 '''
    x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)         # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)         # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv3')(x)         # Добавляем Conv2D-слой с 512-нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    block_4_out = Activation('relu')(x)                                     # Добавляем слой Activation и запоминаем в переменной block_4_out
    x = block_4_out

    ''' UP 2 '''
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)     # Добавляем слой Conv2DTranspose с 256 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = concatenate([x, block_3_out])                                       # Объединяем текущий слой со слоем block_3_out
    x = Conv2D(256, (3, 3), padding='same')(x)                              # Добавляем слой Conv2D с 256 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    ''' UP 3 '''
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)     # Добавляем слой Conv2DTranspose с 128 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = concatenate([x, block_2_out])                                       # Объединяем текущий слой со слоем block_2_out
    x = Conv2D(128, (3, 3), padding='same')(x)                              # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(128, (3, 3), padding='same')(x)                              # Добавляем слой Conv2D с 128 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    ''' UP 4 '''
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)      # Добавляем слой Conv2DTranspose с 64 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = concatenate([x, block_1_out])                                       # Объединяем текущий слой со слоем block_1_out
    x = Conv2D(64, (3, 3), padding='same')(x)                               # Добавляем слой Conv2D с 64 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(64, (3, 3), padding='same')(x)                               # Добавляем слой Conv2D с 64 нейронами
    x = BatchNormalization()(x)                                             # Добавляем слой BatchNormalization
    x = Activation('relu')(x)                                               # Добавляем слой Activation

    x = Conv2D(class_count, (3, 3), activation='softmax', padding='same')(x)  # Добавляем Conv2D-Слой с softmax-активацией на class_count-нейронов

    model = Model(img_input, x)                                             # Создаем модель с входом 'img_input' и выходом 'x'

    # Компилируем модель
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    # Возвращаем сформированную модель
    return model

# %%
# Создание модели и вывод сводки по архитектуре

model_unet = unet(CLASS_COUNT,
                  (IMG_WIDTH, IMG_HEIGHT, 3))

model_unet.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 456,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 256, 456,  │      1,792 │ input_layer_1[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 456,  │        256 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 256, 456,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 256, 456,  │     36,928 │ activation_4[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 456,  │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 256, 456,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 228,  │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 128, 228,  │     73,856 │ max_pooling2d[0]… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 228,  │        512 │ block2_conv1[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 128, 228,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 128, 228,  │    147,584 │ activation_6[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 228,  │        512 │ block2_conv2[0][… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128, 228,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 114,   │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 64, 114,   │    295,168 │ max_pooling2d_1[… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 114,   │      1,024 │ block3_conv1[0][… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 64, 114,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 64, 114,   │    590,080 │ activation_8[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 114,   │      1,024 │ block3_conv2[0][… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 64, 114,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 64, 114,   │    590,080 │ activation_9[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 114,   │      1,024 │ block3_conv3[0][… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 114,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 57,    │          0 │ activation_10[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 32, 57,    │  1,180,160 │ max_pooling2d_2[… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 57,    │      2,048 │ block4_conv1[0][… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 57,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 32, 57,    │  2,359,808 │ activation_11[0]… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 57,    │      2,048 │ block4_conv2[0][… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 32, 57,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 32, 57,    │  2,359,808 │ activation_12[0]… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 57,    │      2,048 │ block4_conv3[0][… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 57,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 114,   │    524,544 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 114,   │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 64, 114,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 114,   │          0 │ activation_14[0]… │
# │ (Concatenate)       │ 512)              │            │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 114,   │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 114,   │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 64, 114,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 114,   │    590,080 │ activation_15[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 114,   │      1,024 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 64, 114,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 228,  │    131,200 │ activation_16[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 228,  │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 128, 228,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 228,  │          0 │ activation_17[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 228,  │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 228,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 128, 228,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 228,  │    147,584 │ activation_18[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 228,  │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 128, 228,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 456,  │     32,832 │ activation_19[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 456,  │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 256, 456,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 456,  │          0 │ activation_20[0]… │
# │ (Concatenate)       │ 128)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 456,  │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 456,  │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 256, 456,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 256, 456,  │     36,928 │ activation_21[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 456,  │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 256, 456,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 256, 456,  │      1,154 │ activation_22[0]… │
# │                     │ 2)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,664,450 (40.68 MB)
#  Trainable params: 10,656,386 (40.65 MB)
#  Non-trainable params: 8,064 (31.50 KB)

# %%
# Обучение модели

history = model_unet.fit(x_train, y_train,
                         epochs=50, batch_size=12,
                         validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - loss: 0.2980 - sparse_categorical_accuracy: 0.8862 - val_loss: 0.2916 - val_sparse_categorical_accuracy: 0.8865
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.2948 - val_sparse_categorical_accuracy: 0.8796
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9642
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.0407 - val_sparse_categorical_accuracy: 0.9861
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0254 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.0450 - val_sparse_categorical_accuracy: 0.9880
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0262 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.0237 - val_sparse_categorical_accuracy: 0.9925
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0248 - val_sparse_categorical_accuracy: 0.9924
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0262 - val_sparse_categorical_accuracy: 0.9914
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0219 - val_sparse_categorical_accuracy: 0.9933
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9930
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0253 - val_sparse_categorical_accuracy: 0.9927
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.0212 - val_sparse_categorical_accuracy: 0.9935
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0212 - val_sparse_categorical_accuracy: 0.9938
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.0100 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0213 - val_sparse_categorical_accuracy: 0.9937
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0247 - val_sparse_categorical_accuracy: 0.9932
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0209 - val_sparse_categorical_accuracy: 0.9941
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.0210 - val_sparse_categorical_accuracy: 0.9942
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0334 - val_sparse_categorical_accuracy: 0.9911
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.1675 - val_sparse_categorical_accuracy: 0.9560
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.2174 - val_sparse_categorical_accuracy: 0.9323
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0205 - val_sparse_categorical_accuracy: 0.9940
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0257 - val_sparse_categorical_accuracy: 0.9926
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0238 - val_sparse_categorical_accuracy: 0.9934
# Epoch 24/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0209 - val_sparse_categorical_accuracy: 0.9941
# Epoch 25/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9941
# Epoch 26/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9943
# Epoch 27/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0216 - val_sparse_categorical_accuracy: 0.9942
# Epoch 28/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0212 - val_sparse_categorical_accuracy: 0.9944
# Epoch 29/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0206 - val_sparse_categorical_accuracy: 0.9947
# Epoch 30/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0215 - val_sparse_categorical_accuracy: 0.9945
# Epoch 31/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.1431 - val_sparse_categorical_accuracy: 0.9639
# Epoch 32/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0161 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0521 - val_sparse_categorical_accuracy: 0.9854
# Epoch 33/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.0194 - val_sparse_categorical_accuracy: 0.9946
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9943
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9944
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9943
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9938
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9942
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0198 - val_sparse_categorical_accuracy: 0.9949
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0227 - val_sparse_categorical_accuracy: 0.9945
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9945
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9949
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0241 - val_sparse_categorical_accuracy: 0.9946
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0244 - val_sparse_categorical_accuracy: 0.9943
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0220 - val_sparse_categorical_accuracy: 0.9948
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0230 - val_sparse_categorical_accuracy: 0.9946
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9948
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 0.9944
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0246 - val_sparse_categorical_accuracy: 0.9944
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0266 - val_sparse_categorical_accuracy: 0.9942

# %%
# Отображение графиков обучения модели

plt.figure(figsize=(14, 7))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.show()

# %% [markdown]
# **Распознавание**

# %%
# Отображение результатов работы модели

process_images(model_unet, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step

# %% [markdown]
# Полученный результат выглядит очень мощно! Модель сегментирует даже самые мелкие детали.
#
# Теперь выведем **5** самых плохих по точности изображений проверочной выборки:

# %%
# Получение массива значений функции ошибки для каждого изображения из проверочной выборки

accuracy = np.array([model_unet.evaluate(x_val[i:i+1],
                                         y_val[i:i+1],
                                         verbose=0)[1] for i in range(x_val.shape[0])])

print(accuracy)
# Out:
# [0.99664199 0.9961794  0.99495441 0.99402928 0.99698466 0.99418348
#  0.99564832 0.99649638 0.9932583  0.99711317 0.99789268 0.99603379
#  0.99858654 0.998124   0.97227079 0.99601668 0.99679619 0.99619657
#  0.99543417 0.99717313 0.99754149 0.99795264 0.99522853 0.99727589
#  0.99573398 0.99893779 0.99685615 0.99326688 0.94221151 0.98918074
#  0.99765283 0.99826103 0.99592245 0.98732185 0.99634218 0.99067128
#  0.99695897 0.99655634 0.99662489 0.99635077 0.99452609 0.99756718
#  0.9969247  0.99569112 0.99425197 0.99725878 0.99664199 0.98661941
#  0.99418348 0.99838954]

# %% [markdown]
# Мы получили массив **accuracy**, в котором сохранены значения **val_sparse_categorical_accuracy** для каждого изображения проверочной выборки. Выберем отсюда **5** худших значений:

# %%
# Получение индексов самых плохих по точности сегментации изображений

print('5 худших по точности сегментации изображений')
bad = np.argsort(accuracy)[:5].tolist()

for b in bad:
    print(f'Изображение №{b} - точность: {accuracy[b]}')
# Out:
# 5 худших по точности сегментации изображений
# Изображение №28 - точность: 0.9422115087509155
# Изображение №14 - точность: 0.9722707867622375
# Изображение №47 - точность: 0.9866194128990173
# Изображение №33 - точность: 0.9873218536376953
# Изображение №29 - точность: 0.9891807436943054

# %% [markdown]
# Выведем на экран результаты работы модели на этих изображениях:

# %%
# Вывод 5 изображений проверочной выборки, на которых модель дает наихудшие результаты

process_images(model_unet, indexes=bad)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step

# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1188DQBNnxXgxxZoldO8cXiQFYaO9PoOh?usp=sharing)
#
# 2. [Практический ноутбук 1](https://colab.research.google.com/drive/1EcHhwOCIhvm4mpxEbDGRawIJ4BpbAyqO?usp=sharing)
#
# 3. [Практический ноутбук 2](https://colab.research.google.com/drive/1pHONL5J4AVraE-SYJnpes7KdicPsD9qt?usp=sharing)
#
# 3. Практический ноутбук 3
